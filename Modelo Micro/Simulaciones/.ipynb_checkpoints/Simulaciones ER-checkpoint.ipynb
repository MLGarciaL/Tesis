# %%
from Winter93ER import NWCap12
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
np.random.seed(1)

n = 3

patentes_totales = []
patentes_totales1 = []
patentes_totales2 = []
patentes_totales3 = []
patentes_totales4 = []
patentes_totales5 = []
At = []
At1 = []
At2 = []
At3 = []
At4 = []
At5 = []
Atmax = []
Atmax1 = []
Atmax2 = []
Atmax3 = []
Atmax4 = []
Atmax5 = []

for _ in range(200):  # Repite 200 veces
    resultados = NWCap12(n = n, patentime = 10, I = 1)
    patentes = sum(sum(sublist) for sublist in resultados.patent_it)
    patentes_totales.append(patentes)
    promedios_A_t = [sum(fila) / len([x for x in fila if x != 0]) if len([x for x in fila if x != 0]) > 0 else 0 for fila in resultados.A_it]

    At.append(promedios_A_t)
    max_values = [max(sublist) for sublist  in resultados.A_it]
    Atmax.append(max_values)

for _ in range(200):  # Repite 200 veces
    resultados = NWCap12(n = n, patentime = 5, I = 1)
    patentes = sum(sum(sublist) for sublist in resultados.patent_it)
    patentes_totales1.append(patentes)
    promedios_A_t = [sum(fila) / len([x for x in fila if x != 0]) if len([x for x in fila if x != 0]) > 0 else 0 for fila in resultados.A_it]

    At1.append(promedios_A_t)
    max_values = [max(sublist) for sublist  in resultados.A_it]
    Atmax1.append(max_values)

for _ in range(200):  # Repite 200 veces
    resultados = NWCap12(n = n, patentime = 0, I = 1)
    patentes = sum(sum(sublist) for sublist in resultados.patent_it)
    patentes_totales2.append(patentes)
    promedios_A_t = [sum(fila) / len([x for x in fila if x != 0]) if len([x for x in fila if x != 0]) > 0 else 0 for fila in resultados.A_it]

    At2.append(promedios_A_t)
    max_values = [max(sublist) for sublist  in resultados.A_it]
    Atmax2.append(max_values)
    

for _ in range(200):  # Repite 200 veces
    resultados = NWCap12(n = n, patentime = 10, I = 0)
    patentes = sum(sum(sublist) for sublist in resultados.patent_it)
    patentes_totales3.append(patentes)
    promedios_A_t = [sum(fila) / len([x for x in fila if x != 0]) if len([x for x in fila if x != 0]) > 0 else 0 for fila in resultados.A_it]
    At3.append(promedios_A_t)
    max_values = [max(sublist) for sublist  in resultados.A_it]
    Atmax3.append(max_values)

for _ in range(200):  # Repite 200 veces
    resultados = NWCap12(n = n, patentime = 5, I = 0)
    patentes = sum(sum(sublist) for sublist in resultados.patent_it)
    patentes_totales4.append(patentes)
    promedios_A_t = [sum(fila) / len([x for x in fila if x != 0]) if len([x for x in fila if x != 0]) > 0 else 0 for fila in resultados.A_it]
    At4.append(promedios_A_t)
    max_values = [max(sublist) for sublist  in resultados.A_it]
    Atmax4.append(max_values)

for _ in range(200):  # Repite 200 veces
    resultados = NWCap12(n = n, patentime = 0, I = 0)
    patentes = sum(sum(sublist) for sublist in resultados.patent_it)
    patentes_totales5.append(patentes)
    promedios_A_t = [sum(fila) / len([x for x in fila if x != 0]) if len([x for x in fila if x != 0]) > 0 else 0 for fila in resultados.A_it]
    At5.append(promedios_A_t)
    max_values = [max(sublist) for sublist  in resultados.A_it]
    Atmax5.append(max_values)

# %%
# Lista de las variables a guardar
listas = {
    "At": At,
    "Atmax": Atmax,
    "patentes_totales": patentes_totales,
    "At1": At1,
    "Atmax1": Atmax1,
    "patentes_totales1": patentes_totales1,
    "At2": At2,
    "Atmax2": Atmax2,
    "patentes_totales2": patentes_totales2,
    "At3": At3,
    "Atmax3": Atmax3,
    "patentes_totales3": patentes_totales3,
    "At4": At4,
    "Atmax4": Atmax4,
    "patentes_totales4": patentes_totales4,
    "At5": At5,
    "Atmax5": Atmax5,
    "patentes_totales5": patentes_totales5
}

with open('Bases\- Simulación n = 3ER.pkl', 'wb') as f:
    pickle.dump(listas, f)

# %%
np.random.seed(2)

n = 5

patentes_totales = []
patentes_totales1 = []
patentes_totales2 = []
patentes_totales3 = []
patentes_totales4 = []
patentes_totales5 = []
At = []
At1 = []
At2 = []
At3 = []
At4 = []
At5 = []
Atmax = []
Atmax1 = []
Atmax2 = []
Atmax3 = []
Atmax4 = []
Atmax5 = []

for _ in range(200):  # Repite 200 veces
    resultados = NWCap12(n = n, patentime = 10, I = 1)
    patentes = sum(sum(sublist) for sublist in resultados.patent_it)
    patentes_totales.append(patentes)
    promedios_A_t = [sum(fila) / len([x for x in fila if x != 0]) if len([x for x in fila if x != 0]) > 0 else 0 for fila in resultados.A_it]

    At.append(promedios_A_t)
    max_values = [max(sublist) for sublist  in resultados.A_it]
    Atmax.append(max_values)

for _ in range(200):  # Repite 200 veces
    resultados = NWCap12(n = n, patentime = 5, I = 1)
    patentes = sum(sum(sublist) for sublist in resultados.patent_it)
    patentes_totales1.append(patentes)
    promedios_A_t = [sum(fila) / len([x for x in fila if x != 0]) if len([x for x in fila if x != 0]) > 0 else 0 for fila in resultados.A_it]

    At1.append(promedios_A_t)
    max_values = [max(sublist) for sublist  in resultados.A_it]
    Atmax1.append(max_values)

for _ in range(200):  # Repite 200 veces
    resultados = NWCap12(n = n, patentime = 0, I = 1)
    patentes = sum(sum(sublist) for sublist in resultados.patent_it)
    patentes_totales2.append(patentes)
    promedios_A_t = [sum(fila) / len([x for x in fila if x != 0]) if len([x for x in fila if x != 0]) > 0 else 0 for fila in resultados.A_it]

    At2.append(promedios_A_t)
    max_values = [max(sublist) for sublist  in resultados.A_it]
    Atmax2.append(max_values)
    

for _ in range(200):  # Repite 200 veces
    resultados = NWCap12(n = n, patentime = 10, I = 0)
    patentes = sum(sum(sublist) for sublist in resultados.patent_it)
    patentes_totales3.append(patentes)
    promedios_A_t = [sum(fila) / len([x for x in fila if x != 0]) if len([x for x in fila if x != 0]) > 0 else 0 for fila in resultados.A_it]
    At3.append(promedios_A_t)
    max_values = [max(sublist) for sublist  in resultados.A_it]
    Atmax3.append(max_values)

for _ in range(200):  # Repite 200 veces
    resultados = NWCap12(n = n, patentime = 5, I = 0)
    patentes = sum(sum(sublist) for sublist in resultados.patent_it)
    patentes_totales4.append(patentes)
    promedios_A_t = [sum(fila) / len([x for x in fila if x != 0]) if len([x for x in fila if x != 0]) > 0 else 0 for fila in resultados.A_it]
    At4.append(promedios_A_t)
    max_values = [max(sublist) for sublist  in resultados.A_it]
    Atmax4.append(max_values)

for _ in range(200):  # Repite 200 veces
    resultados = NWCap12(n = n, patentime = 0, I = 0)
    patentes = sum(sum(sublist) for sublist in resultados.patent_it)
    patentes_totales5.append(patentes)
    promedios_A_t = [sum(fila) / len([x for x in fila if x != 0]) if len([x for x in fila if x != 0]) > 0 else 0 for fila in resultados.A_it]
    At5.append(promedios_A_t)
    max_values = [max(sublist) for sublist  in resultados.A_it]
    Atmax5.append(max_values)

# %%
listas = {
    "At": At,
    "Atmax": Atmax,
    "patentes_totales": patentes_totales,
    "At1": At1,
    "Atmax1": Atmax1,
    "patentes_totales1": patentes_totales1,
    "At2": At2,
    "Atmax2": Atmax2,
    "patentes_totales2": patentes_totales2,
    "At3": At3,
    "Atmax3": Atmax3,
    "patentes_totales3": patentes_totales3,
    "At4": At4,
    "Atmax4": Atmax4,
    "patentes_totales4": patentes_totales4,
    "At5": At5,
    "Atmax5": Atmax5,
    "patentes_totales5": patentes_totales5
}


with open('Bases\- Simulación n = 5ER.pkl', 'wb') as f:
    pickle.dump(listas, f)
